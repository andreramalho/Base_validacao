# %%
import random

# %%
def questao_01():
    # for n in range(10):
    a = random.randint(2, 20)
    b = random.randint(2, 20)
    resp = a * b / 2
    #print(a,b)
    alternativas = []
    alternativas.append(int(resp))
    for n in range(4):
        errada = random.randint(resp*-2, resp*2)
        while errada < 0:
            errada = random.randint(resp*-2, resp*2)
        alternativas.append(errada)
        #print(alternativas)
    #random.shuffle(alternativas)
    #print(alternativas)
    return a, b, alternativas
test = questao_01()
# print('Um triângulo possui base de ' + str(test[0]) + 'cm e a altura relativa a essa base igual a ' + str(test[1]) + 'cm. A área desse triângulo é igual a:')
# print('A. '+str(test[2][0])+'cm')
# print('B. '+str(test[2][1])+'cm')
# print('C. '+str(test[2][2])+'cm')
# print('D. '+str(test[2][3])+'cm')
# print('E. '+str(test[2][4])+'cm')

# %%
def questao_02():
    #
    a = 100
    while a < 0 or a > 9.4:
        a = round(random.random()*10,1)
    #print(a)
    if a < 2.3:
        resp = 'B'
    elif a < 4.7:
        resp = 'C'
    elif a < 7.1:
        resp = 'D'
    elif a < 9.5:
        resp = 'E'
    return a, resp

#print(questao_02()[0])

# %%
def questao_03():
    #
    moedas = {0.01:0.02,
              0.05:0.04,
              0.10:0.05,
              0.25:0.08,
              0.50:0.08,
              1.00:0.09}
    valor1 =random.choice(list(moedas))
    valor2 =random.choice(list(moedas))
    result = moedas[valor1] + moedas[valor2]
    #print(valor)
    #print(moedas[valor])
    return valor1, moedas[valor1], valor2, moedas[valor2], result
#print(questao_03())

# %%
def questao_04():
    #
    x = random.randint(2,5)
    y = random.randint(1,3)
    solve = ((x**2 * (5/y))/20)
    #print(a)
    resp = [solve, solve+0.5, solve+1.5, solve+2.0, solve+2.5]
    #print(x, y, resp)
    return x, y, resp

#questao_04()

# %%
def questao_05():
  #
  Objeto = ['Tritão', 'Vênus', 'Netuno', 'Terra', 'Titã', 'Urano', 'Júpiter', 'Saturno', 'Lua', '1 Ceres', '4 Vesta', 'Marte', '10 Hígia', 'Makemake', 'Haumea', 'Mercúrio', '2 Palas', 'Plutão', '3 Juno', '324 Bamberga', 'Éris', 'Nereida', 'Sedna', 'Cometa Halley', 'Cometa Hale-Bopp', 'Cometa Ikeya-Seki', 'C/1980 E1 (Bowell)', 'ʻOumuamua', '2I/Borisov']
  Excentricidade = [0.00002, 0.0068, 0.0086, 0.0167, 0.0288, 0.0472, 0.0484, 0.0541, 0.0549, 0.0758, 0.0887, 0.0934, 0.1146, 0.1559, 0.1887, 0.2056, 0.2313, 0.2488, 0.2555, 0.3400, 0.4407, 0.7507, 0.8549, 0.9671, 0.9951, 0.9999, 1.057, 1.20, 3.5]    

  lista_nova = {}
  for i,j in zip(Objeto, Excentricidade):
      lista_nova[i] = j

  valor1 =random.choice(list(lista_nova))
  valor2 =random.sample(list(Excentricidade),4)
  #print(lista_nova)
  result = lista_nova[valor1]

  return valor1, result, valor2
#print(questao_05())

# %%
def questao_06():
  #
  Periodo_do_mandato = ['15 de novembro de 1889 -> 23 de novembro de 1891', '23 de novembro de 1891 -> 15 de novembro de 1894', '15 de novembro de 1894 -> 15 de novembro de 1898', '15 de novembro de 1898 -> 15 de novembro de 1902', '15 de novembro de 1902 -> 15 de novembro de 1906', '15 de novembro de 1906 -> 14 de junho de 1909', '14 de junho de 1909 -> 15 de novembro de 1910', '15 de novembro de 1910 -> 15 de novembro de 1914', '15 de novembro de 1914 -> 15 de novembro de 1918', 'Eleito diretamente, morreu antes de tomar posse', '15 de novembro de 1918 -> 28 de julho de 1919', '28 de julho de 1919 -> 15 de novembro de 1922', '15 de novembro de 1922 -> 15 de novembro de 1926', '15 de novembro de 1926 -> 24 de outubro de 1930', 'Eleito diretamente, não assumiu em razão da Revolução de 1930', '24 de outubro de 1930 -> 3 de novembro de 1930', '3 de novembro de 1930 -> 10 de novembro de 1937', '10 de novembro de 1937 -> 29 de outubro de 1945', '29 de outubro de 1945 -> 31 de janeiro de 1946', '31 de janeiro de 1946 -> 31 de janeiro de 1951', '31 de janeiro de 1951 -> 24 de agosto de 1954', '24 de agosto de 1954 -> 8 de novembro de 1955', '8 de novembro de 1955 -> 11 de novembro de 1955', '11 de novembro de 1955 -> 31 de janeiro de 1956', '31 de janeiro de 1956 -> 31 de janeiro de 1961', '31 de janeiro de 1961 -> 25 de agosto de 1961', '25 de agosto de 1961 -> 7 de setembro de 1961', '7 de setembro de 1961 -> 2 de abril de 1964', '2 de abril de 1964 -> 15 de abril de 1964', '15 de abril de 1964 -> 15 de março de 1967', '15 de março de 1967 -> 31 de agosto de 1969', 'Eleito vice-presidente indiretamente, foi impedido de ascender ao cargo de Presidente pela junta militar de 1969.', '31 de agosto de 1969 -> 30 de outubro de 1969', '30 de outubro de 1969 -> 15 de março de 1974', '15 de março de 1974 -> 15 de março de 1979', '15 de março de 1979 -> 15 de março de 1985', 'Eleito indiretamente, morreu antes de tomar posse', '15 de março de 1985 -> 15 de março de 1990', '15 de março de 1990 -> 29 de dezembro de 1992', '29 de dezembro de 1992 -> 1º de janeiro de 1995', '1º de janeiro de 1995 -> 1º de janeiro de 2003', '1º de janeiro de 2003 -> 1º de janeiro de 2011', '1° de janeiro de 2011 -> 31 de agosto de 2016', '31 de agosto de 2016 -> 1º de janeiro de 2019', '1º de janeiro de 2019 -> 1º de janeiro de 2023', '1º de janeiro de 2023 -> atualidade']
  Presidente = ['Deodoro da Fonseca', 'Floriano Peixoto', 'Prudente de Morais', 'Campos Sales', 'Rodrigues Alves', 'Afonso Pena', 'Nilo Peçanha', 'Hermes da Fonseca', 'Venceslau Brás', 'Rodrigues Alves', 'Delfim Moreira', 'Epitácio Pessoa', 'Artur Bernardes', 'Washington Luís', 'Júlio Prestes', 'Junta Governativa Provisória de 1930', 'Getúlio Vargas', 'Getúlio Vargas', 'José Linhares', 'Eurico Gaspar Dutra', 'Getúlio Vargas', 'Café Filho', 'Carlos Luz', 'Nereu Ramos', 'Juscelino Kubitschek', 'Jânio Quadros', 'Ranieri Mazzilli', 'João Goulart', 'Ranieri Mazzilli', 'Humberto Castelo Branco', 'Artur da Costa e Silva', 'Pedro Aleixo', 'Junta militar de 1969', 'Emílio Garrastazu Médici', 'Ernesto Geisel', 'João Figueiredo', 'Tancredo Neves', 'José Sarney', 'Fernando Collor', 'Itamar Franco', 'Fernando Henrique Cardoso', 'Luiz Inácio Lula da Silva', 'Dilma Rousseff', 'Michel Temer', 'Jair Bolsonaro', 'Luiz Inácio Lula da Silva']

  lista_nova = {}
  for i,j in zip(Periodo_do_mandato, Presidente):
      lista_nova[i] = j

  valor1 =random.choice(list(lista_nova))
  valor2 =random.sample(list(Presidente),4)
  #print(lista_nova)
  result = lista_nova[valor1]

  return valor1, result, valor2
#print(questao_06())

# %%
def questao_07():
  #
  tempo_verbal = ['Presente do indicativo', 
                  'Pretérito imperfeito do indicativo', 
                  'Pretérito perfeito do indicativo', 
                  'Pretérito mais-que-perfeito do indicativo', 
                  'Futuro do presente do indicativo', 
                  'Futuro do pretérito do indicativo', 
                  'Presente do subjuntivo', 
                  'Pretérito imperfeito do subjuntivo', 
                  'Futuro do subjuntivo', 
                  'Imperativo afirmativo', 
                  'Imperativo negativo']
  
  conjugacao = ['Eu hei; Tu hás Ele/ela/você há; Nós havemos; Vós haveis; Eles/elas/vocês hão;',
                'Eu havia; Tu havias; Ele/ela/você havia; Nós havíamos; Vós havíeis; Eles/elas/vocês haviam;', 
                'Eu houve; Tu houveste; Ele/ela/você houve; Nós houvemos; Vós houvestes; Eles/elas/vocês houveram;', 
                'Eu houvera; Tu houveras; Ele/ela/você houvera; Nós houvéramos; Vós houvéreis; Eles/elas/vocês houveram;', 
                'Eu haverei; Tu haverás; Ele/ela/você haverá; Nós haveremos; Vós havereis; Eles/elas/vocês haverão', 
                'Eu haveria; Tu haverias; Ele/ela/você haveria; Nós haveríamos; Vós haveríeis; Eles/elas/vocês ; haveriam;', 
                'Que eu haja; Que tu hajas; Que ele/ela/você haja; Que nós hajamos; Que vós hajais; Que eles/elas/vocês hajam', 
                'Se eu houvesse; Se tu houvesses; Se ele/ela/você houvesse; Se nós houvéssemos; Se vós houvésseis; Se eles/elas/vocês houvessem', 
                'Quando eu houver; Quando tu houveres; Quando ele/ela/você houver; Quando nós houvermos; Quando vós houverdes; Quando eles/elas/vocês houverem', 
                'Haja tu; Haja ele/ela/você; Havamos nós; Havei vós; Hajam eles/elas/vocês;', 
                'Não hajas tu; Não haja ele/ela/você; Não havamos nós; Não haveis vós; Não hajam eles/elas/vocês;Eles/elas/vocês houveram;']
  
  lista_nova = {}
  for i,j in zip(tempo_verbal, conjugacao):
      lista_nova[i] = j

  valor1 =random.choice(list(lista_nova))
  valor2 =random.sample(list(conjugacao),4)
  #print(lista_nova)
  result = lista_nova[valor1]

  return valor1, result, valor2
#print(questao_07())

# %%
def questao_08():
    #
    a = round(62.5 / random.randint(3,8),4)
    #print(a)
    if a <= 8:
        resp = 'A'
    elif a <= 9:
        resp = 'B'
    elif a <= 11:
        resp = 'C'
    elif a <= 18:
        resp = 'D'
    elif a <= 24:
        resp = 'E'
    return a, resp
#print(questao_08())

# %%
def questao_09():
  #
  import pandas as pd
  pasta_xml = 'C:\\Users\\andre\\OneDrive\\Mestrado\\_Projeto\\VS-Code\\'
  arquivo = 'tabela_periodica.csv'
  
  tabela_periodica = pd.read_csv(pasta_xml+arquivo, sep=';',on_bad_lines='skip')
  elementos = tabela_periodica['Elemento']
  n_atom = tabela_periodica['Número Atômico']
  simbolo_quim = tabela_periodica['Símbolo']
  #print(len(elementos), len(n_atom), len(simbolo_quim))

  lista_nova = {}
  for i,j in zip(elementos, n_atom):
      lista_nova[i] = j
  #print(lista_nova)
  valor1 =random.choice(list(lista_nova))
  valor2 =random.sample(list(n_atom),4)
  #print(lista_nova)
  result = lista_nova[valor1]

  return valor1, result, valor2
# print(questao_09())

# %%
def questao_10():
  #
  import pandas as pd
  pasta_xml = 'C:\\Users\\andre\\OneDrive\\Mestrado\\_Projeto\\VS-Code\\'
  arquivo = 'tabela_periodica.csv'
  
  tabela_periodica = pd.read_csv(pasta_xml+arquivo, sep=';',on_bad_lines='skip')
  elementos = tabela_periodica['Elemento']
  n_atom = tabela_periodica['Número Atômico']
  simbolo_quim = tabela_periodica['Símbolo']
  #print(len(elementos), len(n_atom), len(simbolo_quim))

  lista_nova = {}
  for i,j in zip(elementos, simbolo_quim):
      lista_nova[i] = j
  #print(lista_nova)
  valor1 =random.choice(list(lista_nova))
  valor2 =random.sample(list(simbolo_quim),4)
  #print(lista_nova)
  result = lista_nova[valor1]

  return valor1, result, valor2
#print(questao_10())

# %%
import random

n_questao = 20
nome_da_prova = 'lista_parametrizadas'
pasta_xml = 'C:\\Users\\andre\\OneDrive\\Mestrado\\_Projeto\\VS-Code\\Questoes_parametrizadas\\'


arquivo = open(pasta_xml + nome_da_prova + '.xml','w')
arquivo.write('''<?xml version="1.0" encoding="UTF-8"?>\n''')
arquivo.write("<QUESTOES>\n")
arquivo.write("	<INFO>\n")
arquivo.write("	<MSG>Questoes parametrizadas para o trabalho.</MSG>\n")
arquivo.write("	</INFO>\n")
arquivo.close()

arquivo = open(pasta_xml + nome_da_prova + '.xml','a', encoding='utf-8')


for n_per in range(1,n_questao+1,1):
  test = questao_01()
  enunciando_01 = 'Um triângulo possui base de ' + str(test[0]) + 'cm e a altura relativa a essa base igual a ' + str(test[1]) + 'cm. A área desse triângulo é igual a:'
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_01 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[2][0]) + 'cm' + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][1]) + 'cm' + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][2]) + 'cm' + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][3]) + 'cm' + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][4]) + 'cm' + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(n_questao+1,2*n_questao+1,1):
  test = questao_02()
  enunciando_02 = '''(Enem PPL 2020) Um caminhão de massa 5 toneladas, carregado com carga de ''' + str(test[0]) + ''' toneladas, tem eixos articulados que permitem fazer o uso de 4 a 12 pneus (aos pares) simultaneamente. O número de pneus em contato com o solo é determinado a fim de que a pressão exercida por cada pneu contra o solo não supere o dobro da pressão atmosférica. A área de contato entre cada pneu e o asfalto equivale à área de um retângulo de lados 20 cm e 30 cm. Considere a aceleração da gravidade local igual a 10 m s−2 e a pressão atmosférica de 105 Pa.'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_02 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>4</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>6</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>8</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>10</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>12</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>''' + test[1] + '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(2*n_questao+1,3*n_questao+1,1):
  test = questao_03()
  enunciando_03 = '''(Enem 2018 PPL) Com um dedo, um garoto pressiona contra a parede duas moedas, de R$ ''' + str(test[0]) + ''' e R$ ''' + str(test[2]) + ''', uma sobre a outra, mantendo-as paradas. Em contato com o dedo está a moeda de R$ ''' + str(test[0]) + ''' e contra a parede está a de R$ ''' + str(test[2]) + '''. O peso da moeda de R$ ''' + str(test[0]) + ''' é ''' + str(test[1]) + ''' N e o da de R$ ''' + str(test[2]) + ''' é ''' + str(test[3]) + ''' N. A força de atrito exercida pela parede é suficiente para impedir que as moedas caiam. Qual é a força de atrito entre a parede e a moeda de R$ ''' + str(test[3]) + '''?'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_03 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[4]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[3]) + '''N</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2]) + '''N</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[1]) + '''N</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[0]) + '''N</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(3*n_questao+1,4*n_questao+1,1):
  test = questao_04()
  enunciando_04 = '''(ENEM 2022) Em um dia de calor intenso, dois colegas estão a brincar com a água da mangueira. Um deles quer saber até que altura o jato de água alcança, a partir da saída de água, quando a mangueira está posicionada totalmente na direção vertical. O outro colega propõe então o seguinte experimento: eles posicionarem a saída de água da mangueira na direção horizontal, a ''' + str(test[0]) + '''m de altura em relação ao chão, e então medirem a distância horizontal entre a mangueira e o local onde a água atinge o chão. A medida dessa distância foi de ''' + str(test[0]) + '''m, e a partir disso eles calcularam o alcance vertical do jato de água. Considere a aceleração da gravidade de 10 m s-2. O resultado que eles obtiveram foi de'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_04 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[2][0]) + 'cm' + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][1]) + 'cm' + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][2]) + 'cm' + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][3]) + 'cm' + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][4]) + 'cm' + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(4*n_questao+1,5*n_questao+1,1):
  test = questao_05()
  enunciando_05 = '''A excentricidade da órbita do objeto chamado ''' + str(test[0]) + ''' é:'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_05 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[1]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][0]) + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][1]) + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][2]) + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][3]) + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(5*n_questao+1,6*n_questao+1,1):
  test = questao_06()
  enunciando_06 = '''No período de ''' + str(test[0]) + ''' quem foi o presidente da república?'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_06 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[1]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][0]) + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][1]) + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][2]) + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][3]) + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(6*n_questao+1,7*n_questao+1,1):
  test = questao_07()
  enunciando_07 = '''Como seria a conjugação do verbo haver no ''' + str(test[0]) + '''?'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_07 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[1]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][0]) + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][1]) + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][2]) + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][3]) + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(7*n_questao+1,8*n_questao+1,1):
  test = questao_08()
  enunciando_08 = '''Uma montadora de automóveis divulgou que oferta a seus clientes mais de 1 000 configurações diferentes de carro, variando o modelo, a motorização, os opcionais e a cor do veículo. Atualmente, ela oferece ''' + str(test[0]) + ''' modelos de carros com 2 tipos de motores: 1.0 e 1.6. Já em relação aos opcionais, existem 3 escolhas possíveis: central multimídia, rodas de liga leve e bancos de couro, podendo o cliente optar por incluir um, dois, três ou nenhum dos opcionais disponíveis. Para ser fiel à divulgação feita, a quantidade mínima de cores que a montadora deverá disponibilizar a seus clientes é'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_08 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>8</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>9</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>11</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>18</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>24</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>''' + str(test[1]) + '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(8*n_questao+1,9*n_questao+1,1):
  test = questao_09()
  enunciando_09 = '''O número atômico do elemento químico ''' + str(test[0]) + ''' é:'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_09 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[1]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][0]) + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][1]) + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][2]) + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][3]) + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


for n_per in range(9*n_questao+1,10*n_questao+1,1):
  test = questao_10()
  enunciando_10 = '''O símbolo do elemento químico ''' + str(test[0]) + ''' é:'''
  arquivo.write('''\n''')
  arquivo.write('''	<QUESTAO qtsNo=' ''' + str(n_per) + ''' '>\n''')
  arquivo.write('''		<ENUNCIADO>''' + enunciando_10 + '''</ENUNCIADO>\n''')
  arquivo.write('''		<ALTERNATIVA_A>''' + str(test[1]) + '''</ALTERNATIVA_A>\n''')
  arquivo.write('''		<ALTERNATIVA_B>''' + str(test[2][0]) + '''</ALTERNATIVA_B>\n''')
  arquivo.write('''		<ALTERNATIVA_C>''' + str(test[2][1]) + '''</ALTERNATIVA_C>\n''')
  arquivo.write('''		<ALTERNATIVA_D>''' + str(test[2][2]) + '''</ALTERNATIVA_D>\n''')
  arquivo.write('''		<ALTERNATIVA_E>''' + str(test[2][3]) + '''</ALTERNATIVA_E>\n''')
  arquivo.write('''		<CORRETA>A''' '''</CORRETA>\n''')
  arquivo.write('''	</QUESTAO>\n''')
  arquivo.write('''\n''')


#arquivo = open('./drive/MyDrive/ENEM_prova_e_gabaritos/' + nome_arquivo_prova + '.txt','a')
arquivo.write("</QUESTOES>\n")
arquivo.close()
